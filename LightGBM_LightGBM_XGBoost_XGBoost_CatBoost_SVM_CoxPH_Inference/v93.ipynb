# %%
# !pip install /kaggle/input/pip-install-lifelines/autograd-1.7.0-py3-none-any.whl
# !pip install /kaggle/input/pip-install-lifelines/autograd-gamma-0.5.0.tar.gz
# !pip install /kaggle/input/pip-install-lifelines/interface_meta-1.3.0-py3-none-any.whl
# !pip install /kaggle/input/pip-install-lifelines/formulaic-1.0.2-py3-none-any.whl
# !pip install /kaggle/input/pip-install-lifelines/lifelines-0.30.0-py3-none-any.whl
# Out:
# Processing /kaggle/input/pip-install-lifelines/autograd-1.7.0-py3-none-any.whl
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from autograd==1.7.0) (1.26.4)
# autograd is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# Processing /kaggle/input/pip-install-lifelines/autograd-gamma-0.5.0.tar.gz
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: autograd>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from autograd-gamma==0.5.0) (1.7.0)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from autograd-gamma==0.5.0) (1.13.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from autograd>=1.2.0->autograd-gamma==0.5.0) (1.26.4)
# Building wheels for collected packages: autograd-gamma
#   Building wheel for autograd-gamma (setup.py) ... done
#   Created wheel for autograd-gamma: filename=autograd_gamma-0.5.0-py3-none-any.whl size=4031 sha256=8cff2689291e5b254c4d056e1191632869e0ea40e719c91f3552cbf35ffe65a3
#   Stored in directory: /root/.cache/pip/wheels/6b/b5/e0/4c79e15c0b5f2c15ecf613c720bb20daab20a666eb67135155
# Successfully built autograd-gamma
# Installing collected packages: autograd-gamma
# Successfully installed autograd-gamma-0.5.0
# Processing /kaggle/input/pip-install-lifelines/interface_meta-1.3.0-py3-none-any.whl
# Installing collected packages: interface-meta
# Successfully installed interface-meta-1.3.0
# Processing /kaggle/input/pip-install-lifelines/formulaic-1.0.2-py3-none-any.whl
# Requirement already satisfied: interface-meta>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from formulaic==1.0.2) (1.3.0)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from formulaic==1.0.2) (1.26.4)
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.10/dist-packages (from formulaic==1.0.2) (2.1.4)
# Requirement already satisfied: scipy>=1.6 in /usr/local/lib/python3.10/dist-packages (from formulaic==1.0.2) (1.13.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from formulaic==1.0.2) (4.12.2)
# Requirement already satisfied: wrapt>=1.0 in /usr/local/lib/python3.10/dist-packages (from formulaic==1.0.2) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0->formulaic==1.0.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0->formulaic==1.0.2) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0->formulaic==1.0.2) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0->formulaic==1.0.2) (1.16.0)
# Installing collected packages: formulaic
# Successfully installed formulaic-1.0.2
# Processing /kaggle/input/pip-install-lifelines/lifelines-0.30.0-py3-none-any.whl
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from lifelines==0.30.0) (1.26.4)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from lifelines==0.30.0) (1.13.1)
# Requirement already satisfied: pandas>=2.1 in /usr/local/lib/python3.10/dist-packages (from lifelines==0.30.0) (2.1.4)
# Requirement already satisfied: matplotlib>=3.0 in /usr/local/lib/python3.10/dist-packages (from lifelines==0.30.0) (3.7.1)
# Requirement already satisfied: autograd>=1.5 in /usr/local/lib/python3.10/dist-packages (from lifelines==0.30.0) (1.7.0)
# Requirement already satisfied: autograd-gamma>=0.3 in /usr/local/lib/python3.10/dist-packages (from lifelines==0.30.0) (0.5.0)
# Requirement already satisfied: formulaic>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from lifelines==0.30.0) (1.0.2)
# Requirement already satisfied: interface-meta>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from formulaic>=0.2.2->lifelines==0.30.0) (1.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from formulaic>=0.2.2->lifelines==0.30.0) (4.12.2)
# Requirement already satisfied: wrapt>=1.0 in /usr/local/lib/python3.10/dist-packages (from formulaic>=0.2.2->lifelines==0.30.0) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0->lifelines==0.30.0) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0->lifelines==0.30.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0->lifelines==0.30.0) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0->lifelines==0.30.0) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0->lifelines==0.30.0) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0->lifelines==0.30.0) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0->lifelines==0.30.0) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0->lifelines==0.30.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.1->lifelines==0.30.0) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.1->lifelines==0.30.0) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0->lifelines==0.30.0) (1.16.0)
# Installing collected packages: lifelines
# Successfully installed lifelines-0.30.0

# %%
import warnings
warnings.simplefilter(action='ignore')

import os
import requests
import joblib

import numpy
import pandas

import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
from catboost import CatBoostRegressor ,Pool
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

from lifelines import KaplanMeierFitter, CoxPHFitter, LogNormalFitter, LogLogisticFitter, ExponentialFitter, WeibullFitter

from sklearn.linear_model import ElasticNetCV, LassoCV, RidgeCV
from sklearn.svm import SVR

from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import StackingRegressor
from sklearn.ensemble import AdaBoostRegressor

from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import accuracy_score

from sklearn.pipeline import make_pipeline
from sklearn.model_selection import KFold, cross_val_score

from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from sklearn.feature_selection import SelectFromModel

from sklearn.impute import SimpleImputer
import sklearn.linear_model as linear_model
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %%
train = pandas.read_csv('/kaggle/input/equity-post-HCT-survival-predictions/train.csv').drop(columns=['ID'])
test = pandas.read_csv('/kaggle/input/equity-post-HCT-survival-predictions/test.csv').drop(columns=['ID'])

# %%
def calculate_survival_probabilities(df, time_col, event_col):
    cph = CoxPHFitter()
    cph.fit(df, duration_col='efs_time', event_col='efs')
    df['target'] = cph.predict_partial_hazard(df)
    return df

def preprocess_survival_data(df, time_col='efs_time', event_col='efs'):
    df = calculate_survival_probabilities(df, time_col, event_col)
    #df.loc[df[event_col] == 0, 'target'] -= 0.2  # Adjust for censored data
    return df

# %%
encoder = LabelEncoder()
normalize = SimpleImputer(strategy='mean')

# %%
for i in zip(train.columns,train.dtypes):
    if i[1]=='O':
        train[i[0]] = train[i[0]].fillna('Unknown')
        train[i[0]]=encoder.fit_transform(train[i[0]].to_numpy().reshape(-1,1))
    else:
        train[i[0]] = train[i[0]].fillna(0)
        #train[i[0]]=normalize.fit_transform(numpy.array(train[i[0]]).reshape(-1,1))
for i in zip(test.columns,test.dtypes):
    if i[1]=='O':
        test[i[0]] = test[i[0]].fillna('Unknown')
        test[i[0]]=encoder.fit_transform(test[i[0]].to_numpy().reshape(-1,1))
    else:
        test[i[0]] = test[i[0]].fillna(0)
        #test[i[0]]=normalize.fit_transform(numpy.array(test[i[0]]).reshape(-1,1))

# %%
train = preprocess_survival_data(train)

train_x = train.drop(columns=['efs', 'efs_time', 'target'])
train_y = train['target']
    
#train.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8)

#clf = GradientBoostingRegressor(n_estimators=100).fit(train_x, train_y)
#model = SelectFromModel(clf, prefit=True)

#weight = model.transform(train_x).reshape(-1)
train.head()
# Out:
#    dri_score  psych_disturb  cyto_score  diabetes  hla_match_c_high  \
# 0          7              0           7         0               0.0
# 1          2              0           1         0               2.0
# 2          7              0           7         0               2.0
# 3          0              0           1         0               2.0
# 4          0              0           7         0               2.0
#
#    hla_high_res_8  tbi_status  arrhythmia  hla_low_res_6  graft_type  ...  \
# 0             0.0           0           0            6.0           0  ...
# 1             8.0           6           0            6.0           1  ...
# 2             8.0           0           0            6.0           0  ...
# 3             8.0           0           0            6.0           0  ...
# 4             8.0           0           0            6.0           1  ...
#
#    donor_related  melphalan_dose  hla_low_res_8  cardiac  hla_match_drb1_high  \
# 0              3               1            8.0        0                  2.0
# 1              1               1            8.0        0                  2.0
# 2              1               1            8.0        0                  2.0
# 3              3               1            8.0        0                  2.0
# 4              1               0            8.0        0                  2.0
#
#    pulm_moderate  hla_low_res_10  efs  efs_time    target
# 0              0            10.0  0.0    42.356  0.404255
# 1              3            10.0  1.0     4.672  2.042602
# 2              0            10.0  0.0    19.793  0.361195
# 3              0            10.0  0.0   102.349  1.129620
# 4              0            10.0  0.0    16.223  0.876989
#
# [5 rows x 60 columns]

# %%
Fold=5
kf = KFold(n_splits=Fold)

cat_pre_train = numpy.zeros(len(train))
cat_pre_test = numpy.zeros(len(test))

catboost = StackingRegressor(estimators=[('catboost', CatBoostRegressor( grow_policy='Depthwise', iterations=1000, 
                                 eval_metric='RMSE', random_state=0, verbose=100)), ('lightgbm', LGBMRegressor())])

for i, (train_index, test_index) in enumerate(kf.split(train)):

    print(f"FOLD: {i}")

    x_fold=train_x[train_index[0]: train_index[len(train_index)-1]]
    y_fold=train_y[train_index[0]: train_index[len(train_index)-1]]

    x_test_fold=train_x[test_index[0]: test_index[len(test_index)-1]]
    y_test_fold=train_y[test_index[0]: test_index[len(test_index)-1]]

    cat_features = list(train_x.select_dtypes(include=['object', 'category']).columns)

    #val_pool = (x_test_fold, y_test_fold)
    
    #weight_ = weight[train_index[0]: train_index[len(train_index)-1]]
    
    catboost.fit(x_fold, y_fold)

    cat_pre_train+=catboost.predict(train_x)
    cat_pre_test+=catboost.predict(test)

    print(catboost.score(x_test_fold, y_test_fold))
# Out:
# FOLD: 0
# Learning rate set to 0.067212
# 0:	learn: 0.5612455	total: 72.8ms	remaining: 1m 12s
# 100:	learn: 0.1492788	total: 1.44s	remaining: 12.8s
# 200:	learn: 0.0911518	total: 2.75s	remaining: 10.9s
# 300:	learn: 0.0654526	total: 4.04s	remaining: 9.38s
# 400:	learn: 0.0525790	total: 5.32s	remaining: 7.95s
# 500:	learn: 0.0446547	total: 6.63s	remaining: 6.61s
# 600:	learn: 0.0391839	total: 7.88s	remaining: 5.23s
# 700:	learn: 0.0352386	total: 9.11s	remaining: 3.88s
# 800:	learn: 0.0321382	total: 10.3s	remaining: 2.57s
# 900:	learn: 0.0294684	total: 11.6s	remaining: 1.27s
# 999:	learn: 0.0272369	total: 12.8s	remaining: 0us
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.008495 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 811
# [LightGBM] [Info] Number of data points in the train set: 23039, number of used features: 57
# [LightGBM] [Info] Start training from score 1.141076
# Learning rate set to 0.064884
# 0:	learn: 0.5642630	total: 13.6ms	remaining: 13.6s
# 100:	learn: 0.1514683	total: 1.22s	remaining: 10.8s
# 200:	learn: 0.0921630	total: 2.46s	remaining: 9.79s
# 300:	learn: 0.0660394	total: 3.95s	remaining: 9.18s
# 400:	learn: 0.0527761	total: 5.17s	remaining: 7.72s
# 500:	learn: 0.0444309	total: 6.31s	remaining: 6.29s
# 600:	learn: 0.0389281	total: 7.43s	remaining: 4.93s
# 700:	learn: 0.0350499	total: 8.54s	remaining: 3.64s
# 800:	learn: 0.0316817	total: 9.66s	remaining: 2.4s
# 900:	learn: 0.0287195	total: 10.8s	remaining: 1.18s
# 999:	learn: 0.0264688	total: 11.9s	remaining: 0us
# Learning rate set to 0.064884
# 0:	learn: 0.5655318	total: 12.3ms	remaining: 12.2s
# 100:	learn: 0.1516994	total: 1.28s	remaining: 11.4s
# 200:	learn: 0.0924414	total: 2.46s	remaining: 9.8s
# 300:	learn: 0.0649386	total: 3.61s	remaining: 8.39s
# 400:	learn: 0.0515525	total: 4.74s	remaining: 7.08s
# 500:	learn: 0.0434696	total: 5.88s	remaining: 5.85s
# 600:	learn: 0.0379384	total: 7s	remaining: 4.65s
# 700:	learn: 0.0338089	total: 8.12s	remaining: 3.46s
# 800:	learn: 0.0304908	total: 9.24s	remaining: 2.3s
# 900:	learn: 0.0280900	total: 10.4s	remaining: 1.14s
# 999:	learn: 0.0260066	total: 11.5s	remaining: 0us
# Learning rate set to 0.064884
# 0:	learn: 0.5552937	total: 12.2ms	remaining: 12.2s
# 100:	learn: 0.1514808	total: 1.22s	remaining: 10.9s
# 200:	learn: 0.0927770	total: 2.4s	remaining: 9.53s
# 300:	learn: 0.0660135	total: 3.54s	remaining: 8.22s
# 400:	learn: 0.0524965	total: 4.68s	remaining: 6.99s
# 500:	learn: 0.0439606	total: 5.82s	remaining: 5.8s
# 600:	learn: 0.0383645	total: 6.95s	remaining: 4.61s
# 700:	learn: 0.0343100	total: 8.05s	remaining: 3.44s
# 800:	learn: 0.0312448	total: 9.21s	remaining: 2.29s
# 900:	learn: 0.0284711	total: 10.3s	remaining: 1.13s
# 999:	learn: 0.0263963	total: 11.6s	remaining: 0us
# Learning rate set to 0.064884
# 0:	learn: 0.5591992	total: 14.7ms	remaining: 14.6s
# 100:	learn: 0.1518330	total: 1.38s	remaining: 12.2s
# 200:	learn: 0.0922517	total: 2.61s	remaining: 10.4s
# 300:	learn: 0.0656972	total: 3.79s	remaining: 8.81s
# 400:	learn: 0.0520572	total: 4.96s	remaining: 7.41s
# 500:	learn: 0.0438442	total: 6.11s	remaining: 6.08s
# 600:	learn: 0.0384133	total: 7.31s	remaining: 4.85s
# 700:	learn: 0.0345414	total: 8.4s	remaining: 3.58s
# 800:	learn: 0.0312806	total: 9.52s	remaining: 2.36s
# 900:	learn: 0.0285508	total: 10.6s	remaining: 1.17s
# 999:	learn: 0.0263703	total: 11.7s	remaining: 0us
# Learning rate set to 0.064884
# 0:	learn: 0.5670623	total: 15ms	remaining: 15s
# 100:	learn: 0.1528800	total: 1.29s	remaining: 11.5s
# 200:	learn: 0.0922402	total: 2.48s	remaining: 9.87s
# 300:	learn: 0.0655955	total: 3.66s	remaining: 8.5s
# 400:	learn: 0.0518475	total: 4.87s	remaining: 7.28s
# 500:	learn: 0.0439429	total: 5.99s	remaining: 5.96s
# 600:	learn: 0.0385836	total: 7.1s	remaining: 4.71s
# 700:	learn: 0.0344783	total: 8.22s	remaining: 3.51s
# 800:	learn: 0.0313225	total: 9.32s	remaining: 2.31s
# 900:	learn: 0.0287183	total: 10.4s	remaining: 1.14s
# 999:	learn: 0.0264342	total: 11.5s	remaining: 0us
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004700 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 811
# [LightGBM] [Info] Number of data points in the train set: 18431, number of used features: 57
# [LightGBM] [Info] Start training from score 1.138015
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004733 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 811
# [LightGBM] [Info] Number of data points in the train set: 18431, number of used features: 57
# [LightGBM] [Info] Start training from score 1.140403
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004677 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 811
# [LightGBM] [Info] Number of data points in the train set: 18431, number of used features: 57
# [LightGBM] [Info] Start training from score 1.139940
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004604 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 811
# [LightGBM] [Info] Number of data points in the train set: 18431, number of used features: 57
# [LightGBM] [Info] Start training from score 1.142210
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004680 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 811
# [LightGBM] [Info] Number of data points in the train set: 18432, number of used features: 57
# [LightGBM] [Info] Start training from score 1.144810
# 0.982387056844171
# FOLD: 1
# Learning rate set to 0.069624
# 0:	learn: 0.5632351	total: 26.9ms	remaining: 26.9s
# 100:	learn: 0.1497376	total: 1.61s	remaining: 14.4s
# 200:	learn: 0.0928081	total: 3.14s	remaining: 12.5s
# 300:	learn: 0.0679046	total: 4.86s	remaining: 11.3s
# 400:	learn: 0.0550888	total: 6.63s	remaining: 9.91s
# 500:	learn: 0.0474061	total: 8.1s	remaining: 8.07s
# 600:	learn: 0.0420553	total: 9.54s	remaining: 6.34s
# 700:	learn: 0.0379725	total: 11s	remaining: 4.71s
# 800:	learn: 0.0347501	total: 12.6s	remaining: 3.13s
# 900:	learn: 0.0318989	total: 14s	remaining: 1.54s
# 999:	learn: 0.0295928	total: 15.5s	remaining: 0us
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.008673 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 811
# [LightGBM] [Info] Number of data points in the train set: 28799, number of used features: 57
# [LightGBM] [Info] Start training from score 1.141981
# Learning rate set to 0.067212
# 0:	learn: 0.5612455	total: 19.1ms	remaining: 19.1s
# 100:	learn: 0.1492788	total: 1.47s	remaining: 13.1s
# 200:	learn: 0.0911518	total: 2.88s	remaining: 11.5s
# 300:	learn: 0.0654526	total: 4.29s	remaining: 9.97s
# 400:	learn: 0.0525790	total: 5.6s	remaining: 8.37s
# 500:	learn: 0.0446547	total: 6.92s	remaining: 6.89s
# 600:	learn: 0.0391839	total: 8.21s	remaining: 5.45s
# 700:	learn: 0.0352386	total: 9.54s	remaining: 4.07s
# 800:	learn: 0.0321382	total: 10.9s	remaining: 2.7s
# 900:	learn: 0.0294684	total: 12.1s	remaining: 1.33s
# 999:	learn: 0.0272369	total: 13.4s	remaining: 0us
# Learning rate set to 0.067212
# 0:	learn: 0.5672188	total: 16.1ms	remaining: 16.1s
# 100:	learn: 0.1499858	total: 1.66s	remaining: 14.8s
# 200:	learn: 0.0917950	total: 3.08s	remaining: 12.2s
# 300:	learn: 0.0663647	total: 4.49s	remaining: 10.4s
# 400:	learn: 0.0532526	total: 5.88s	remaining: 8.78s
# 500:	learn: 0.0450241	total: 7.62s	remaining: 7.58s
# 600:	learn: 0.0398356	total: 9.14s	remaining: 6.07s
# 700:	learn: 0.0357696	total: 10.5s	remaining: 4.49s
# 800:	learn: 0.0325384	total: 11.9s	remaining: 2.96s
# 900:	learn: 0.0297705	total: 13.4s	remaining: 1.47s
# 999:	learn: 0.0276180	total: 14.8s	remaining: 0us
# Learning rate set to 0.067212
# 0:	learn: 0.5649298	total: 19.2ms	remaining: 19.2s
# 100:	learn: 0.1506850	total: 1.85s	remaining: 16.4s
# 200:	learn: 0.0921922	total: 3.56s	remaining: 14.1s
# 300:	learn: 0.0662945	total: 5.19s	remaining: 12.1s
# 400:	learn: 0.0534220	total: 6.54s	remaining: 9.77s
# 500:	learn: 0.0457038	total: 7.86s	remaining: 7.83s
# 600:	learn: 0.0404883	total: 9.19s	remaining: 6.1s
# 700:	learn: 0.0363544	total: 10.5s	remaining: 4.49s
# 800:	learn: 0.0331672	total: 11.8s	remaining: 2.94s
# 900:	learn: 0.0304090	total: 13.1s	remaining: 1.44s
# 999:	learn: 0.0280559	total: 14.4s	remaining: 0us
# Learning rate set to 0.067212
# 0:	learn: 0.5599856	total: 15.1ms	remaining: 15.1s
# 100:	learn: 0.1507997	total: 1.46s	remaining: 13s
# 200:	learn: 0.0918246	total: 2.87s	remaining: 11.4s
# 300:	learn: 0.0660190	total: 4.26s	remaining: 9.89s
# 400:	learn: 0.0531628	total: 5.57s	remaining: 8.32s
# 500:	learn: 0.0453672	total: 6.89s	remaining: 6.86s
# 600:	learn: 0.0399213	total: 8.23s	remaining: 5.46s
# 700:	learn: 0.0357876	total: 9.87s	remaining: 4.21s
# 800:	learn: 0.0324595	total: 11.4s	remaining: 2.82s
# 900:	learn: 0.0296792	total: 12.6s	remaining: 1.39s
# 999:	learn: 0.0275426	total: 13.9s	remaining: 0us
# Learning rate set to 0.067213
# 0:	learn: 0.5683162	total: 15.3ms	remaining: 15.3s
# 100:	learn: 0.1525785	total: 1.54s	remaining: 13.7s
# 200:	learn: 0.0926938	total: 3.06s	remaining: 12.2s
# 300:	learn: 0.0665365	total: 4.46s	remaining: 10.4s
# 400:	learn: 0.0532590	total: 6.01s	remaining: 8.98s
# 500:	learn: 0.0459045	total: 7.3s	remaining: 7.27s
# 600:	learn: 0.0406646	total: 8.57s	remaining: 5.69s
# 700:	learn: 0.0368065	total: 9.8s	remaining: 4.18s
# 800:	learn: 0.0335925	total: 11.1s	remaining: 2.75s
# 900:	learn: 0.0307623	total: 12.3s	remaining: 1.35s
# 999:	learn: 0.0282854	total: 13.6s	remaining: 0us
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005645 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 811
# [LightGBM] [Info] Number of data points in the train set: 23039, number of used features: 57
# [LightGBM] [Info] Start training from score 1.141076
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005740 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 811
# [LightGBM] [Info] Number of data points in the train set: 23039, number of used features: 57
# [LightGBM] [Info] Start training from score 1.139525
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005587 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 811
# [LightGBM] [Info] Number of data points in the train set: 23039, number of used features: 57
# [LightGBM] [Info] Start training from score 1.143292
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009605 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 811
# [LightGBM] [Info] Number of data points in the train set: 23039, number of used features: 57
# [LightGBM] [Info] Start training from score 1.140637
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005555 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 811
# [LightGBM] [Info] Number of data points in the train set: 23040, number of used features: 57
# [LightGBM] [Info] Start training from score 1.145375
# 0.9964165256363465
# FOLD: 2
# Learning rate set to 0.069624
# 0:	learn: 0.5632351	total: 16.4ms	remaining: 16.4s
# 100:	learn: 0.1497376	total: 1.64s	remaining: 14.6s
# 200:	learn: 0.0928081	total: 3.19s	remaining: 12.7s
# 300:	learn: 0.0679046	total: 4.74s	remaining: 11s
# 400:	learn: 0.0550888	total: 6.22s	remaining: 9.3s
# 500:	learn: 0.0474061	total: 7.81s	remaining: 7.78s
# 600:	learn: 0.0420553	total: 9.35s	remaining: 6.21s
# 700:	learn: 0.0379725	total: 11.3s	remaining: 4.83s
# 800:	learn: 0.0347501	total: 12.8s	remaining: 3.19s
# 900:	learn: 0.0318989	total: 14.4s	remaining: 1.58s
# 999:	learn: 0.0295928	total: 15.9s	remaining: 0us
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.008199 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 811
# [LightGBM] [Info] Number of data points in the train set: 28799, number of used features: 57
# [LightGBM] [Info] Start training from score 1.141981
# Learning rate set to 0.067212
# 0:	learn: 0.5612455	total: 15.3ms	remaining: 15.3s
# 100:	learn: 0.1492788	total: 1.54s	remaining: 13.7s
# 200:	learn: 0.0911518	total: 2.92s	remaining: 11.6s
# 300:	learn: 0.0654526	total: 4.26s	remaining: 9.89s
# 400:	learn: 0.0525790	total: 5.6s	remaining: 8.36s
# 500:	learn: 0.0446547	total: 7.05s	remaining: 7.03s
# 600:	learn: 0.0391839	total: 8.39s	remaining: 5.57s
# 700:	learn: 0.0352386	total: 9.71s	remaining: 4.14s
# 800:	learn: 0.0321382	total: 11.2s	remaining: 2.77s
# 900:	learn: 0.0294684	total: 12.7s	remaining: 1.4s
# 999:	learn: 0.0272369	total: 14.2s	remaining: 0us
# Learning rate set to 0.067212
# 0:	learn: 0.5672188	total: 15.1ms	remaining: 15.1s
# 100:	learn: 0.1499858	total: 1.64s	remaining: 14.6s
# 200:	learn: 0.0917950	total: 3.1s	remaining: 12.3s
# 300:	learn: 0.0663647	total: 4.64s	remaining: 10.8s
# 400:	learn: 0.0532526	total: 6.02s	remaining: 8.99s
# 500:	learn: 0.0450241	total: 7.43s	remaining: 7.4s
# 600:	learn: 0.0398356	total: 8.76s	remaining: 5.82s
# 700:	learn: 0.0357696	total: 10.1s	remaining: 4.3s
# 800:	learn: 0.0325384	total: 11.7s	remaining: 2.91s
# 900:	learn: 0.0297705	total: 13.3s	remaining: 1.46s
# 999:	learn: 0.0276180	total: 14.6s	remaining: 0us
# Learning rate set to 0.067212
# 0:	learn: 0.5649298	total: 16.4ms	remaining: 16.4s
# 100:	learn: 0.1506850	total: 1.56s	remaining: 13.9s
# 200:	learn: 0.0921922	total: 2.98s	remaining: 11.9s
# 300:	learn: 0.0662945	total: 4.27s	remaining: 9.93s
# 400:	learn: 0.0534220	total: 5.58s	remaining: 8.34s
# 500:	learn: 0.0457038	total: 6.85s	remaining: 6.83s
# 600:	learn: 0.0404883	total: 8.14s	remaining: 5.4s
# 700:	learn: 0.0363544	total: 9.43s	remaining: 4.02s
# 800:	learn: 0.0331672	total: 10.7s	remaining: 2.65s
# 900:	learn: 0.0304090	total: 12s	remaining: 1.32s
# 999:	learn: 0.0280559	total: 13.4s	remaining: 0us
# Learning rate set to 0.067212
# 0:	learn: 0.5599856	total: 13.8ms	remaining: 13.7s
# 100:	learn: 0.1507997	total: 1.45s	remaining: 12.9s
# 200:	learn: 0.0918246	total: 2.86s	remaining: 11.4s
# 300:	learn: 0.0660190	total: 4.18s	remaining: 9.71s
# 400:	learn: 0.0531628	total: 5.52s	remaining: 8.25s
# 500:	learn: 0.0453672	total: 6.89s	remaining: 6.87s
# 600:	learn: 0.0399213	total: 8.21s	remaining: 5.45s
# 700:	learn: 0.0357876	total: 9.48s	remaining: 4.04s
# 800:	learn: 0.0324595	total: 10.7s	remaining: 2.67s
# 900:	learn: 0.0296792	total: 12s	remaining: 1.32s
# 999:	learn: 0.0275426	total: 13.2s	remaining: 0us
# Learning rate set to 0.067213
# 0:	learn: 0.5683162	total: 14ms	remaining: 14s
# 100:	learn: 0.1525785	total: 1.76s	remaining: 15.7s
# 200:	learn: 0.0926938	total: 3.39s	remaining: 13.5s
# 300:	learn: 0.0665365	total: 4.77s	remaining: 11.1s
# 400:	learn: 0.0532590	total: 6.05s	remaining: 9.04s
# 500:	learn: 0.0459045	total: 7.35s	remaining: 7.32s
# 600:	learn: 0.0406646	total: 8.63s	remaining: 5.73s
# 700:	learn: 0.0368065	total: 9.94s	remaining: 4.24s
# 800:	learn: 0.0335925	total: 11.2s	remaining: 2.78s
# 900:	learn: 0.0307623	total: 12.4s	remaining: 1.36s
# 999:	learn: 0.0282854	total: 13.7s	remaining: 0us
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005486 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 811
# [LightGBM] [Info] Number of data points in the train set: 23039, number of used features: 57
# [LightGBM] [Info] Start training from score 1.141076
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005958 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 811
# [LightGBM] [Info] Number of data points in the train set: 23039, number of used features: 57
# [LightGBM] [Info] Start training from score 1.139525
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006002 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 811
# [LightGBM] [Info] Number of data points in the train set: 23039, number of used features: 57
# [LightGBM] [Info] Start training from score 1.143292
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005590 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 811
# [LightGBM] [Info] Number of data points in the train set: 23039, number of used features: 57
# [LightGBM] [Info] Start training from score 1.140637
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005519 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 811
# [LightGBM] [Info] Number of data points in the train set: 23040, number of used features: 57
# [LightGBM] [Info] Start training from score 1.145375
# 0.9965651312641656
# FOLD: 3
# Learning rate set to 0.069624
# 0:	learn: 0.5632351	total: 15.7ms	remaining: 15.7s
# 100:	learn: 0.1497376	total: 1.61s	remaining: 14.3s
# 200:	learn: 0.0928081	total: 3.11s	remaining: 12.4s
# 300:	learn: 0.0679046	total: 4.58s	remaining: 10.6s
# 400:	learn: 0.0550888	total: 6.04s	remaining: 9.03s
# 500:	learn: 0.0474061	total: 7.53s	remaining: 7.5s
# 600:	learn: 0.0420553	total: 8.98s	remaining: 5.96s
# 700:	learn: 0.0379725	total: 10.4s	remaining: 4.43s
# 800:	learn: 0.0347501	total: 11.8s	remaining: 2.94s
# 900:	learn: 0.0318989	total: 13.3s	remaining: 1.46s
# 999:	learn: 0.0295928	total: 14.7s	remaining: 0us
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.007658 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 811
# [LightGBM] [Info] Number of data points in the train set: 28799, number of used features: 57
# [LightGBM] [Info] Start training from score 1.141981
# Learning rate set to 0.067212
# 0:	learn: 0.5612455	total: 18.3ms	remaining: 18.3s
# 100:	learn: 0.1492788	total: 1.92s	remaining: 17.1s
# 200:	learn: 0.0911518	total: 3.31s	remaining: 13.2s
# 300:	learn: 0.0654526	total: 4.64s	remaining: 10.8s
# 400:	learn: 0.0525790	total: 5.92s	remaining: 8.85s
# 500:	learn: 0.0446547	total: 7.24s	remaining: 7.21s
# 600:	learn: 0.0391839	total: 8.56s	remaining: 5.69s
# 700:	learn: 0.0352386	total: 9.83s	remaining: 4.19s
# 800:	learn: 0.0321382	total: 11.1s	remaining: 2.76s
# 900:	learn: 0.0294684	total: 12.4s	remaining: 1.36s
# 999:	learn: 0.0272369	total: 13.7s	remaining: 0us
# Learning rate set to 0.067212
# 0:	learn: 0.5672188	total: 13.2ms	remaining: 13.2s
# 100:	learn: 0.1499858	total: 1.38s	remaining: 12.3s
# 200:	learn: 0.0917950	total: 2.71s	remaining: 10.8s
# 300:	learn: 0.0663647	total: 4.05s	remaining: 9.41s
# 400:	learn: 0.0532526	total: 5.35s	remaining: 7.99s
# 500:	learn: 0.0450241	total: 6.61s	remaining: 6.58s
# 600:	learn: 0.0398356	total: 7.9s	remaining: 5.25s
# 700:	learn: 0.0357696	total: 9.15s	remaining: 3.9s
# 800:	learn: 0.0325384	total: 10.4s	remaining: 2.58s
# 900:	learn: 0.0297705	total: 11.7s	remaining: 1.28s
# 999:	learn: 0.0276180	total: 12.9s	remaining: 0us
# Learning rate set to 0.067212
# 0:	learn: 0.5649298	total: 13.5ms	remaining: 13.5s
# 100:	learn: 0.1506850	total: 1.45s	remaining: 12.9s
# 200:	learn: 0.0921922	total: 2.78s	remaining: 11.1s
# 300:	learn: 0.0662945	total: 4.1s	remaining: 9.53s
# 400:	learn: 0.0534220	total: 5.56s	remaining: 8.31s
# 500:	learn: 0.0457038	total: 7.13s	remaining: 7.1s
# 600:	learn: 0.0404883	total: 8.43s	remaining: 5.59s
# 700:	learn: 0.0363544	total: 9.69s	remaining: 4.13s
# 800:	learn: 0.0331672	total: 10.9s	remaining: 2.72s
# 900:	learn: 0.0304090	total: 12.2s	remaining: 1.34s
# 999:	learn: 0.0280559	total: 13.4s	remaining: 0us
# Learning rate set to 0.067212
# 0:	learn: 0.5599856	total: 14.1ms	remaining: 14.1s
# 100:	learn: 0.1507997	total: 1.46s	remaining: 13s
# 200:	learn: 0.0918246	total: 2.8s	remaining: 11.1s
# 300:	learn: 0.0660190	total: 4.12s	remaining: 9.57s
# 400:	learn: 0.0531628	total: 5.41s	remaining: 8.08s
# 500:	learn: 0.0453672	total: 6.67s	remaining: 6.64s
# 600:	learn: 0.0399213	total: 7.93s	remaining: 5.27s
# 700:	learn: 0.0357876	total: 9.19s	remaining: 3.92s
# 800:	learn: 0.0324595	total: 10.5s	remaining: 2.61s
# 900:	learn: 0.0296792	total: 11.7s	remaining: 1.29s
# 999:	learn: 0.0275426	total: 13s	remaining: 0us
# Learning rate set to 0.067213
# 0:	learn: 0.5683162	total: 14.1ms	remaining: 14.1s
# 100:	learn: 0.1525785	total: 1.37s	remaining: 12.2s
# 200:	learn: 0.0926938	total: 2.7s	remaining: 10.7s
# 300:	learn: 0.0665365	total: 4.03s	remaining: 9.36s
# 400:	learn: 0.0532590	total: 5.33s	remaining: 7.96s
# 500:	learn: 0.0459045	total: 6.59s	remaining: 6.56s
# 600:	learn: 0.0406646	total: 7.89s	remaining: 5.24s
# 700:	learn: 0.0368065	total: 9.1s	remaining: 3.88s
# 800:	learn: 0.0335925	total: 10.4s	remaining: 2.57s
# 900:	learn: 0.0307623	total: 11.9s	remaining: 1.31s
# 999:	learn: 0.0282854	total: 13.3s	remaining: 0us
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005479 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 811
# [LightGBM] [Info] Number of data points in the train set: 23039, number of used features: 57
# [LightGBM] [Info] Start training from score 1.141076
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005755 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 811
# [LightGBM] [Info] Number of data points in the train set: 23039, number of used features: 57
# [LightGBM] [Info] Start training from score 1.139525
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005494 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 811
# [LightGBM] [Info] Number of data points in the train set: 23039, number of used features: 57
# [LightGBM] [Info] Start training from score 1.143292
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005765 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 811
# [LightGBM] [Info] Number of data points in the train set: 23039, number of used features: 57
# [LightGBM] [Info] Start training from score 1.140637
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005539 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 811
# [LightGBM] [Info] Number of data points in the train set: 23040, number of used features: 57
# [LightGBM] [Info] Start training from score 1.145375
# 0.9968597818601367
# FOLD: 4
# Learning rate set to 0.067212
# 0:	learn: 0.5683346	total: 17.2ms	remaining: 17.1s
# 100:	learn: 0.1518457	total: 1.48s	remaining: 13.2s
# 200:	learn: 0.0929957	total: 2.81s	remaining: 11.2s
# 300:	learn: 0.0667868	total: 4.1s	remaining: 9.52s
# 400:	learn: 0.0539406	total: 5.39s	remaining: 8.05s
# 500:	learn: 0.0461194	total: 6.66s	remaining: 6.63s
# 600:	learn: 0.0404887	total: 7.92s	remaining: 5.26s
# 700:	learn: 0.0368187	total: 9.14s	remaining: 3.9s
# 800:	learn: 0.0335795	total: 10.4s	remaining: 2.58s
# 900:	learn: 0.0309623	total: 11.6s	remaining: 1.27s
# 999:	learn: 0.0287889	total: 12.8s	remaining: 0us
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005605 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 811
# [LightGBM] [Info] Number of data points in the train set: 23039, number of used features: 57
# [LightGBM] [Info] Start training from score 1.145363
# Learning rate set to 0.064884
# 0:	learn: 0.5672707	total: 12.8ms	remaining: 12.8s
# 100:	learn: 0.1536766	total: 1.23s	remaining: 11s
# 200:	learn: 0.0922322	total: 2.42s	remaining: 9.61s
# 300:	learn: 0.0650129	total: 3.58s	remaining: 8.32s
# 400:	learn: 0.0517452	total: 4.74s	remaining: 7.08s
# 500:	learn: 0.0438605	total: 5.89s	remaining: 5.87s
# 600:	learn: 0.0382739	total: 7.07s	remaining: 4.7s
# 700:	learn: 0.0344331	total: 8.16s	remaining: 3.48s
# 800:	learn: 0.0313280	total: 9.25s	remaining: 2.3s
# 900:	learn: 0.0286653	total: 10.4s	remaining: 1.14s
# 999:	learn: 0.0264918	total: 11.4s	remaining: 0us
# Learning rate set to 0.064884
# 0:	learn: 0.5697274	total: 12.9ms	remaining: 12.9s
# 100:	learn: 0.1516893	total: 1.47s	remaining: 13.1s
# 200:	learn: 0.0920343	total: 2.86s	remaining: 11.4s
# 300:	learn: 0.0648265	total: 4.02s	remaining: 9.33s
# 400:	learn: 0.0518063	total: 5.19s	remaining: 7.76s
# 500:	learn: 0.0439036	total: 6.31s	remaining: 6.29s
# 600:	learn: 0.0387525	total: 7.42s	remaining: 4.93s
# 700:	learn: 0.0345889	total: 8.55s	remaining: 3.65s
# 800:	learn: 0.0314495	total: 9.64s	remaining: 2.39s
# 900:	learn: 0.0287660	total: 10.7s	remaining: 1.18s
# 999:	learn: 0.0265984	total: 11.8s	remaining: 0us
# Learning rate set to 0.064884
# 0:	learn: 0.5767602	total: 12.9ms	remaining: 12.9s
# 100:	learn: 0.1538354	total: 1.23s	remaining: 10.9s
# 200:	learn: 0.0928365	total: 2.4s	remaining: 9.55s
# 300:	learn: 0.0658125	total: 3.61s	remaining: 8.38s
# 400:	learn: 0.0521838	total: 4.74s	remaining: 7.08s
# 500:	learn: 0.0442097	total: 5.86s	remaining: 5.84s
# 600:	learn: 0.0389205	total: 6.97s	remaining: 4.62s
# 700:	learn: 0.0349618	total: 8.09s	remaining: 3.45s
# 800:	learn: 0.0317529	total: 9.22s	remaining: 2.29s
# 900:	learn: 0.0291406	total: 10.3s	remaining: 1.13s
# 999:	learn: 0.0271714	total: 11.3s	remaining: 0us
# Learning rate set to 0.064884
# 0:	learn: 0.5672567	total: 12ms	remaining: 12s
# 100:	learn: 0.1542301	total: 1.3s	remaining: 11.6s
# 200:	learn: 0.0916009	total: 2.48s	remaining: 9.86s
# 300:	learn: 0.0653111	total: 3.63s	remaining: 8.44s
# 400:	learn: 0.0522993	total: 4.78s	remaining: 7.14s
# 500:	learn: 0.0446769	total: 5.91s	remaining: 5.89s
# 600:	learn: 0.0390458	total: 7.02s	remaining: 4.66s
# 700:	learn: 0.0349443	total: 8.14s	remaining: 3.47s
# 800:	learn: 0.0315927	total: 9.35s	remaining: 2.32s
# 900:	learn: 0.0289870	total: 10.7s	remaining: 1.18s
# 999:	learn: 0.0269019	total: 12s	remaining: 0us
# Learning rate set to 0.064884
# 0:	learn: 0.5666693	total: 13.7ms	remaining: 13.7s
# 100:	learn: 0.1538694	total: 1.24s	remaining: 11s
# 200:	learn: 0.0926922	total: 2.41s	remaining: 9.6s
# 300:	learn: 0.0656222	total: 3.57s	remaining: 8.3s
# 400:	learn: 0.0523788	total: 4.71s	remaining: 7.04s
# 500:	learn: 0.0443421	total: 5.87s	remaining: 5.85s
# 600:	learn: 0.0389451	total: 6.99s	remaining: 4.64s
# 700:	learn: 0.0348835	total: 8.09s	remaining: 3.45s
# 800:	learn: 0.0317315	total: 9.23s	remaining: 2.29s
# 900:	learn: 0.0289794	total: 10.3s	remaining: 1.14s
# 999:	learn: 0.0267434	total: 11.4s	remaining: 0us
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004559 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 811
# [LightGBM] [Info] Number of data points in the train set: 18431, number of used features: 57
# [LightGBM] [Info] Start training from score 1.145093
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004529 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 811
# [LightGBM] [Info] Number of data points in the train set: 18431, number of used features: 57
# [LightGBM] [Info] Start training from score 1.142965
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004363 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 811
# [LightGBM] [Info] Number of data points in the train set: 18431, number of used features: 57
# [LightGBM] [Info] Start training from score 1.145682
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004429 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 811
# [LightGBM] [Info] Number of data points in the train set: 18431, number of used features: 57
# [LightGBM] [Info] Start training from score 1.148251
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004494 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 811
# [LightGBM] [Info] Number of data points in the train set: 18432, number of used features: 57
# [LightGBM] [Info] Start training from score 1.144823
# 0.9835012014748477

# %%
id = pandas.read_csv('/kaggle/input/equity-post-HCT-survival-predictions/test.csv')['ID']
test_predictions = (cat_pre_test/Fold)
#((RandomF_pre_test/Fold)+(LGBM_pre_test/Fold)+(xgb_pre_test/Fold)+(cat_pre_test/Fold))/4
#model.predict(new_test_data)
#((RandomF_pre_test/10)+(LGBM_pre_test/5)+(xgb_pre_test/5)+(cat_pre_test/5))/4
test_predictions
# Out:
# array([0.40207338, 1.66204291, 0.40083907])

# %%
submission = pandas.DataFrame({
    'ID': id.values,
    'prediction': test_predictions,
})
submission
# Out:
#       ID  prediction
# 0  28800    0.402073
# 1  28801    1.662043
# 2  28802    0.400839

# %%
submission.to_csv('submission.csv', index = False)
